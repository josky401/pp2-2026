# %% [markdown]
# # 나의 프로젝트 노트
#
# 중요한 코드나 문서를 함께 작성할 거에요.
#
# - 작성일: 2026.09.08
# - 작성자: 조하늘
#
# 그 외에 표나 그림 등도 넣을 수 있어요.

# %%
print("Hello, World")
x = 3
print("x=",x)
# Out:
# Hello, World
# x= 3

# %% [markdown]
# 이 알고리즘은 아주 간단합니다. 백트래킹 알고리즘을 사용하였으며, DFS 기반을 사용했습니다.
